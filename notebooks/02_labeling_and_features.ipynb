# %% [markdown]
# # 02 — Labeling and Feature Engineering
#
# ### Project: Online Retail Engagement Risk Prediction
# ### Notebook: 02_labeling_and_features.ipynb
#
# **Goals:**
# - Define a churn label using a forward-looking prediction horizon
# - Build a leakage-safe snapshot-based modeling dataset
# - Engineer rolling behavioral features across multiple time windows
# - Evaluate baseline heuristics to establish benchmarks for modeling
#
# **Inputs:**
# - `data/processed/orders.parquet` — cleaned order-level table from notebook 01
#
# **Outputs:**
# - `data/processed/modeling_dataset.parquet` — full labeled modeling dataset
#
# **Steps:**
# - Load and validate orders table
# - Define weekly snapshot dates
# - Implement leakage-safe engagement label function
# - Implement rolling-window feature engineering function
# - Validate on single test snapshot
# - Build full dataset across all valid snapshots
# - Evaluate recency heuristic and all-churn baselines
# - Persist modeling dataset to parquet

# %%
# ─────────────────────────────────────────────────────────────
# Imports and Data Load
# ─────────────────────────────────────────────────────────────

import pandas as pd
import numpy as np
from pathlib import Path
from datetime import timedelta

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    roc_auc_score,
    average_precision_score,
)

orders = pd.read_parquet("../data/processed/orders.parquet")

print("Orders shape:", orders.shape)
print("Dtypes:\n", orders.dtypes)
print("Date range:", orders["order_ts"].min(), "→", orders["order_ts"].max())
print("Unique customers:", orders["Customer ID"].nunique())
print("Unique invoices: ", orders["Invoice"].nunique())
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Orders shape: (19213, 7)
# Dtypes:
#  Customer ID              object
# Invoice                  object
# order_ts         datetime64[ns]
# total_revenue           float64
# total_qty                 int64
# n_items                   int64
# n_lines                   int64
# dtype: object
# Date range: 2009-12-01 07:45:00 → 2010-12-09 20:01:00
# Unique customers: 4312
# Unique invoices:  19213

# %% [markdown]
# ## Pipeline Overview
#
# The core challenge in building a churn prediction dataset from transaction
# logs is **temporal leakage** — the accidental use of future information
# to predict the past. A randomly shuffled train/test split would allow
# the model to learn from future orders when predicting past churn, producing
# inflated performance estimates that collapse in deployment.
#
# This notebook solves the problem using a **snapshot-based approach**:
#
# 1. Select a series of weekly snapshot dates spanning the dataset
# 2. For each snapshot date T, compute features using only orders at or
#    before T — nothing from the future leaks in
# 3. Define the label by looking forward: did the customer place any order
#    in the next 30 days after T?
# 4. Each row in the final dataset represents a distinct customer-snapshot
#    pair: *"what did we know about customer C at time T, and did they
#    churn in the following 30 days?"*
#
# This mirrors real deployment conditions exactly — the model always
# predicts the future from the past.

# %%
# ─────────────────────────────────────────────────────────────
# Snapshot Dates
# Generate weekly snapshot dates from the order history.
# Each snapshot date represents a "as of" moment in time —
# features are computed from orders at or before this date.
# ─────────────────────────────────────────────────────────────

snapshot_dates = (
    orders["order_ts"]
    .dt.to_period("W")
    .dt.start_time
    .sort_values()
    .unique()
)

# Remove snapshots before the first order timestamp
min_ts = orders["order_ts"].min()
snapshot_dates = [s for s in snapshot_dates if s >= min_ts]

print(f"Total snapshot dates: {len(snapshot_dates)}")
print(f"First snapshot: {snapshot_dates[0].date()}")
print(f"Last snapshot:  {snapshot_dates[-1].date()}")
# Out:
# Total snapshot dates: 52
# First snapshot: 2009-12-07
# Last snapshot:  2010-12-06

# %%
# ─────────────────────────────────────────────────────────────
# Engagement Label Function
#
# Label = 1 if customer makes no purchase in the next
#         horizon_days after snapshot_date (disengaged)
# Label = 0 if customer does make a purchase (engaged)
#
# Only customers with at least one order at or before the
# snapshot date are included — cold-start customers are excluded.
# ─────────────────────────────────────────────────────────────

def label_engagement(orders, snapshot_date, horizon_days=30):
    horizon_end = snapshot_date + timedelta(days=horizon_days)

    users_active_before = orders.loc[
        orders["order_ts"] <= snapshot_date, "Customer ID"
    ].unique()

    future_orders = orders.loc[
        (orders["order_ts"] > snapshot_date) &
        (orders["order_ts"] <= horizon_end)
    ]

    users_active_future = set(future_orders["Customer ID"].unique())

    labels = []
    for u in users_active_before:
        labels.append({
            "Customer ID":  u,
            "snapshot_date": snapshot_date,
            "label":        int(u not in users_active_future)
        })

    # Explicit columns ensure consistent joins downstream
    return pd.DataFrame(
        labels,
        columns=["Customer ID", "snapshot_date", "label"]
    )

# %%
# ─────────────────────────────────────────────────────────────
# Label Function — Single Snapshot Test
# ─────────────────────────────────────────────────────────────

test_snapshot = snapshot_dates[9]
labels_df     = label_engagement(orders, test_snapshot)

print(f"Test snapshot: {test_snapshot.date()}")
print(f"Customers labeled: {len(labels_df)}")
print("\nLabel distribution:")
print(labels_df["label"].value_counts(normalize=True).round(4))
# Out:
# Test snapshot: 2010-02-15
# Customers labeled: 1536
#
# Label distribution:
# label
# 1    0.6693
# 0    0.3307
# Name: proportion, dtype: float64

# %% [markdown]
# ## Feature Engineering
#
# ### Time Window Design
#
# Three rolling windows are computed for each customer at each snapshot date,
# capturing behavioral signal at different time horizons:
#
# | Window | Captures |
# |---|---|
# | 7 days | Short-term engagement — recent activity signal |
# | 30 days | Medium-term behavior — monthly purchasing patterns |
# | 90 days | Long-term value — sustained engagement and loyalty |
#
# Within each window, three metrics are computed: order count, total revenue,
# and item diversity. Combined with recency and lifetime aggregates, this
# produces 12 features per customer-snapshot pair.
#
# All features use only orders with `order_ts <= snapshot_date` — no future
# data is accessible to the feature builder at any point.

# %%
# ─────────────────────────────────────────────────────────────
# Feature Engineering Function
#
# Builds leakage-safe rolling behavioral features for all
# customers active at or before snapshot_date.
#
# Features per customer:
#   recency_days         — days since most recent order
#   orders_{w}d          — order count in window
#   revenue_{w}d         — total revenue in window
#   items_{w}d           — unique items purchased in window
#   lifetime_orders      — total orders up to snapshot
#   lifetime_revenue     — total revenue up to snapshot
# ─────────────────────────────────────────────────────────────

def build_features(orders, snapshot_date, windows=(7, 30, 90)):
    snap_orders = orders[orders["order_ts"] <= snapshot_date].copy()

    features = []

    for customer_id, hist in snap_orders.groupby("Customer ID"):
        feat = {
            "Customer ID":   customer_id,
            "snapshot_date": snapshot_date,
        }

        last_order_date    = hist["order_ts"].max()
        feat["recency_days"] = (snapshot_date - last_order_date).days

        for w in windows:
            start      = snapshot_date - pd.Timedelta(days=w)
            win        = hist[hist["order_ts"] > start]
            feat[f"orders_{w}d"]  = len(win)
            feat[f"revenue_{w}d"] = win["total_revenue"].sum()
            feat[f"items_{w}d"]   = win["n_items"].sum()

        feat["lifetime_orders"]  = len(hist)
        feat["lifetime_revenue"] = hist["total_revenue"].sum()

        features.append(feat)

    cols = (
        ["Customer ID", "snapshot_date", "recency_days"] +
        [f"orders_{w}d"  for w in windows] +
        [f"revenue_{w}d" for w in windows] +
        [f"items_{w}d"   for w in windows] +
        ["lifetime_orders", "lifetime_revenue"]
    )

    # Explicit column order ensures consistent joins downstream
    return pd.DataFrame(features, columns=cols)

# %%
# ─────────────────────────────────────────────────────────────
# Feature Function — Single Snapshot Test
# ─────────────────────────────────────────────────────────────

X_df = build_features(orders, test_snapshot)

print(f"Feature matrix shape: {X_df.shape}")
X_df.head()
# Out:
# Feature matrix shape: (1536, 14)
#   Customer ID snapshot_date  recency_days  orders_7d  orders_30d  orders_90d  \
# 0       12346    2010-02-15            23          0           1           9
# 1       12358    2010-02-15            68          0           0           1
# 2       12359    2010-02-15            60          0           0           2
# 3       12361    2010-02-15            19          0           1           1
# 4       12362    2010-02-15            75          0           0           1
#
#    revenue_7d  revenue_30d  revenue_90d  items_7d  items_30d  items_90d  \
# 0         0.0         22.5       203.50         0          1          9
# 1         0.0          0.0      1429.83         0          0         17
# 2         0.0          0.0       838.89         0          0         34
# 3         0.0        109.2       109.20         0          7          7
# 4         0.0          0.0       130.00         0          0          1
#
# ...

# %%
# ─────────────────────────────────────────────────────────────
# Join Features and Labels — Single Snapshot Test
# ─────────────────────────────────────────────────────────────

model_df = (
    X_df
    .merge(labels_df, on=["Customer ID", "snapshot_date"], how="inner")
)

print("Joined dataset shape:", model_df.shape)
print("\nLabel distribution:")
print(model_df["label"].value_counts(normalize=True).round(4))
# Out:
# Joined dataset shape: (1536, 15)
#
# Label distribution:
# label
# 1    0.6693
# 0    0.3307
# Name: proportion, dtype: float64

# %% [markdown]
# ## Feature and Label Definitions
#
# ### Identifier / Metadata
# | Column | Description |
# |---|---|
# | `Customer ID` | Unique customer identifier |
# | `snapshot_date` | The "as of" date — features reflect behavior up to this point |
#
# ### Behavioral Features
# | Column | Description |
# |---|---|
# | `recency_days` | Days since the customer's most recent order as of snapshot_date |
# | `orders_7d` | Orders placed in the 7 days prior to snapshot_date |
# | `revenue_7d` | Total revenue in the 7 days prior to snapshot_date |
# | `items_7d` | Unique items purchased in the 7 days prior to snapshot_date |
# | `orders_30d` | Orders placed in the 30 days prior to snapshot_date |
# | `revenue_30d` | Total revenue in the 30 days prior to snapshot_date |
# | `items_30d` | Unique items purchased in the 30 days prior to snapshot_date |
# | `orders_90d` | Orders placed in the 90 days prior to snapshot_date |
# | `revenue_90d` | Total revenue in the 90 days prior to snapshot_date |
# | `items_90d` | Unique items purchased in the 90 days prior to snapshot_date |
# | `lifetime_orders` | Total orders placed by the customer up to snapshot_date |
# | `lifetime_revenue` | Total revenue generated by the customer up to snapshot_date |
#
# ### Label
# | Value | Meaning |
# |---|---|
# | `1` | Customer made no purchase in the next 30 days — **disengaged** |
# | `0` | Customer made at least one purchase in the next 30 days — **engaged** |
#
# ### Row Interpretation
# Each row answers the question: *"At snapshot date T, customer C had the
# following behavioral history — did they disengage in the following 30 days?"*
# Everything except the label is computed using data at or before T.

# %%
# ─────────────────────────────────────────────────────────────
# Feature and Target Split — Single Snapshot
# Used here for baseline evaluation only.
# Full multi-snapshot dataset is built below.
# ─────────────────────────────────────────────────────────────

feature_cols = [
    "recency_days",
    "orders_7d",  "revenue_7d",  "items_7d",
    "orders_30d", "revenue_30d", "items_30d",
    "orders_90d", "revenue_90d", "items_90d",
    "lifetime_orders", "lifetime_revenue",
]

X = model_df[feature_cols]
y = model_df["label"]

print("Feature matrix shape:", X.shape)
print("Label shape:         ", y.shape)
# Out:
# Feature matrix shape: (1536, 12)
# Label shape:          (1536,)

# %% [markdown]
# ## Baseline Evaluation
#
# Before building any ML model, we establish two baselines that any useful
# model must beat:
#
# 1. **Recency heuristic** — predict churn if the customer has not purchased
#    in the last 30 days. This is the most intuitive simple rule.
# 2. **All-churn classifier** — predict churn for every customer. Since the
#    dataset is ~67% churn, this is a surprisingly strong dummy baseline.
#
# The base rate (label prevalence) is the churn rate across the test snapshot:

# %%
# ─────────────────────────────────────────────────────────────
# Base Rate (Label Prevalence)
# ─────────────────────────────────────────────────────────────

base_rate = y.mean()
print(f"Base churn rate: {base_rate:.4f} ({base_rate:.1%})")
print("Interpretation: a model that predicts everyone churns would")
print(f"achieve {base_rate:.1%} accuracy — this is the floor to beat.")
# Out:
# Base churn rate: 0.6693 (66.9%)
# Interpretation: a model that predicts everyone churns would
# achieve 66.9% accuracy — this is the floor to beat.

# %%
# ─────────────────────────────────────────────────────────────
# Recency Heuristic Baseline
# Predict churn if customer has not ordered in the last 30 days
# ─────────────────────────────────────────────────────────────

RECENCY_THRESHOLD = 30
baseline_pred = (model_df["recency_days"] > RECENCY_THRESHOLD).astype(int)

print(f"Recency heuristic (>{RECENCY_THRESHOLD} days) flags "
      f"{baseline_pred.mean():.1%} of customers as at-risk")
# Out:
# Recency heuristic (>30 days) flags 44.2% of customers as at-risk

# %%
# ─────────────────────────────────────────────────────────────
# Baseline Accuracy
# ─────────────────────────────────────────────────────────────

baseline_accuracy = (baseline_pred == y).mean()
print(f"Recency heuristic accuracy: {baseline_accuracy:.4f} ({baseline_accuracy:.1%})")
print(f"All-churn accuracy:         {base_rate:.4f} ({base_rate:.1%})")
print(f"\nThe recency heuristic underperforms the all-churn baseline,")
print(f"confirming that recency alone is not a sufficient predictor.")
# Out:
# Recency heuristic accuracy: 0.5215 (52.1%)
# All-churn accuracy:         0.6693 (66.9%)
#
# The recency heuristic underperforms the all-churn baseline,
# confirming that recency alone is not a sufficient predictor.

# %% [markdown]
# The recency heuristic achieves only approx. 52% accuracy — worse than the
# all-churn baseline (approx. 67%). This is a meaningful finding: a rule that
# flags anyone inactive for 30 days misclassifies more customers than
# simply predicting everyone churns.
#
# This happens because the heuristic has poor recall — it misses a large
# fraction of true churners who happened to order recently but then
# disengaged. **Recency alone is not sufficient.** A useful model must
# incorporate frequency and monetary signals alongside recency — which is
# exactly what the rolling-window features are designed to provide.
#
# Since the dataset is ~67% churn, accuracy is a misleading metric here.
# We now evaluate precision and recall explicitly.

# %%
# ─────────────────────────────────────────────────────────────
# Formal Baseline Evaluation
# Recency heuristic vs. all-churn classifier
# ─────────────────────────────────────────────────────────────

all_churn_pred = np.ones_like(y)

print("─" * 45)
print(f"{'Metric':<20} {'Recency':>10} {'All-Churn':>10}")
print("─" * 45)
for metric_name, metric_fn in [
    ("Accuracy",  accuracy_score),
    ("Precision", precision_score),
    ("Recall",    recall_score),
]:
    rec_score = metric_fn(y, baseline_pred)
    ac_score  = metric_fn(y, all_churn_pred)
    print(f"{metric_name:<20} {rec_score:>10.4f} {ac_score:>10.4f}")
print("─" * 45)
# Out:
# ─────────────────────────────────────────────
# Metric                  Recency  All-Churn
# ─────────────────────────────────────────────
# Accuracy                 0.5215     0.6693
# Precision                0.7158     0.6693
# Recall                   0.4728     1.0000
# ─────────────────────────────────────────────

# %% [markdown]
# ### Baseline Metric Interpretation
#
# **Recency Heuristic (predict churn if recency_days > 30):**
#
# - **Accuracy (~52%):** Worse than the all-churn baseline — confirms the
#   heuristic is actively harmful as a standalone rule
# - **Precision (~72%):** When the heuristic does flag a customer, it is
#   right about 72% of the time — reasonable, but not actionable alone
# - **Recall (~47%):** The heuristic catches fewer than half of true
#   churners — missing over 50% of at-risk customers is unacceptable
#   for a re-engagement program
#
# **All-Churn Classifier (predict churn for everyone):**
#
# - **Accuracy and Precision (~67%):** Equal to the base rate — the model
#   adds no discrimination, just reflects the class distribution
# - **Recall (100%):** Catches every churner by definition, but at the
#   cost of flagging every non-churner as well
#
# **What a good ML model needs to do:**
# Beat the recency heuristic on recall while maintaining comparable
# precision, and beat the all-churn baseline on discrimination — meaning
# it must rank customers by risk rather than flagging everyone uniformly.

# %% [markdown]
# ## Full Dataset Construction
#
# The single-snapshot test above validated the labeling and feature
# functions. We now build the complete modeling dataset by iterating
# across all valid snapshot dates.
#
# **Important:** Snapshots within the final 30 days of the dataset are
# excluded — there is insufficient future data to compute a valid churn
# label for those snapshots. Only snapshots with a full 30-day forward
# window are used.
#
# The horizon and feature windows are configurable below:

# %%
# ─────────────────────────────────────────────────────────────
# Full Dataset Configuration
# HORIZON_DAYS — forward window for churn label definition
# WINDOWS      — rolling feature window sizes in days
# ─────────────────────────────────────────────────────────────

HORIZON_DAYS = 30          # days forward to define churn
WINDOWS      = (7, 30, 90) # rolling feature windows

# Exclude snapshots without a full forward horizon
max_order_ts           = orders["order_ts"].max()
latest_snapshot_allowed = max_order_ts - pd.Timedelta(days=HORIZON_DAYS)
snapshots_used         = [s for s in snapshot_dates
                          if s <= latest_snapshot_allowed]

print(f"Total snapshots available: {len(snapshot_dates)}")
print(f"Snapshots used:            {len(snapshots_used)}")
print(f"Snapshots excluded:        {len(snapshot_dates) - len(snapshots_used)}")
print(f"First snapshot used: {snapshots_used[0].date()}")
print(f"Last snapshot used:  {snapshots_used[-1].date()}")
# Out:
# Total snapshots available: 52
# Snapshots used:            48
# Snapshots excluded:        4
# First snapshot used: 2009-12-07
# Last snapshot used:  2010-11-08

# %%
# ─────────────────────────────────────────────────────────────
# Full Dataset Build Loop
# Iterates over all valid snapshots, builds features and labels
# for each, and concatenates into a single modeling dataset.
# Skips any snapshot with no eligible customers.
# ─────────────────────────────────────────────────────────────

all_rows = []

for i, snap in enumerate(snapshots_used):
    labels_df = label_engagement(orders, snap, horizon_days=HORIZON_DAYS)
    X_df      = build_features(orders, snap, windows=WINDOWS)

    if labels_df.empty or X_df.empty:
        print(f"Skipping {snap.date()} — no eligible customers")
        continue

    df_snap = X_df.merge(
        labels_df, on=["Customer ID", "snapshot_date"], how="inner"
    )
    all_rows.append(df_snap)

    if (i + 1) % 10 == 0 or (i + 1) == len(snapshots_used):
        print(f"Snapshot {i+1}/{len(snapshots_used)} "
              f"[{snap.date()}] — rows: {df_snap.shape[0]}")

full_model_df = pd.concat(all_rows, ignore_index=True)

print(f"\nFull dataset shape: {full_model_df.shape}")
print(f"Overall churn rate: {full_model_df['label'].mean():.4f}")
# Out:
# Snapshot 10/48 [2010-02-15] — rows: 1536
# Snapshot 20/48 [2010-04-26] — rows: 2370
# Snapshot 30/48 [2010-07-05] — rows: 3001
# Snapshot 40/48 [2010-09-13] — rows: 3385
# Snapshot 48/48 [2010-11-08] — rows: 4013
#
# Full dataset shape: (120261, 15)
# Overall churn rate: 0.7098

# %%
# ─────────────────────────────────────────────────────────────
# Persist Full Modeling Dataset
# Saved to data/processed/ — excluded from version control
# via .gitignore. Run this notebook to regenerate.
# ─────────────────────────────────────────────────────────────

out_dir  = Path("../data/processed")
out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / "modeling_dataset.parquet"

full_model_df.to_parquet(out_path, index=False)

print("Saved to:", out_path)
print("Shape:   ", full_model_df.shape)
print("Churn rate:", full_model_df["label"].mean().round(4))
# Out:
# Saved to: ../data/processed/modeling_dataset.parquet
# Shape:    (120261, 15)
# Churn rate: 0.7098
