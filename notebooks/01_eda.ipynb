# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# ### Project: Online Retail Engagement Risk Prediction
# ### Notebook: 01_eda.ipynb
#
# **Goals:**
# - Understand the raw transaction data structure
# - Assess data quality and perform cleaning
# - Diagnose filtered records and quantify cancellation signal
# - Construct an order-level event table with cancellation features
# - Establish dataset time range and basic statistics
#
# **Inputs:**
# - `online_retail_II.xlsx` — UCI Online Retail Dataset
#
# **Outputs:**
# - `data/processed/orders.parquet` — cleaned order-level table with cancellation features
#
# **Steps:**
# - Load and inspect raw transaction data
# - Diagnose filtered records — quantify exclusion reasons and customer overlap
# - Clean data — drop missing IDs, separate cancellations from gross purchases
# - Construct order-level aggregation table with per-customer cancellation features
# - Persist orders table to parquet
# - Analyze revenue, order frequency, and cancellation distributions

# %%
# ─────────────────────────────────────────────────────────────
# Load Raw Data
# ─────────────────────────────────────────────────────────────

import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

DATA_PATH = Path("../data/raw")
files = list(DATA_PATH.glob("*.xls*"))

df = pd.read_excel(files[0])

print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
print("Date range:", df["InvoiceDate"].min(), "→", df["InvoiceDate"].max())
print("Unique customers:", df["Customer ID"].nunique())

df.head()
# Out:
# Shape: (525461, 8)
# Columns: ['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'Price', 'Customer ID', 'Country']
# Date range: 2009-12-01 07:45:00 → 2010-12-09 20:01:00
# Unique customers: 4383
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# ## Dataset Description
#
# The raw dataset contains **525,461 transactions** across **8 columns**, spanning
# early December 2009 to early December 2010, with **4,383 unique customers**.
#
# We define a customer engagement event as: **one invoice = one order event.**
#
# Each row represents a single line item within an order. Orders are identified
# by a unique Invoice ID and will be aggregated to the order level in the next step.

# %% [markdown]
# ## Diagnosing Filtered Records
#
# Before finalizing cleaning logic, we quantify what the original pipeline was
# discarding and assess whether any of it contains usable signal. This analysis
# directly informs the cleaning and feature engineering decisions in the steps
# that follow.

# %%
# ─────────────────────────────────────────────────────────────
# Quantify Excluded Records
# Break down the ~118k filtered rows by exclusion reason
# to assess whether we're discarding useful signal.
# ─────────────────────────────────────────────────────────────

# Reload raw data for comparison (df is already in memory from earlier)
null_id    = df["Customer ID"].isna()
cancel     = df["Invoice"].astype(str).str.startswith("C")
non_pos_qty = df["Quantity"] <= 0
zero_price = df["Price"] <= 0

print(f"Total raw rows:              {len(df):,}")
print(f"Null Customer ID:            {null_id.sum():,}")
print(f"Cancellations (C-prefix):    {cancel.sum():,}")
print(f"Non-positive quantity:       {non_pos_qty.sum():,}")
print(f"Zero/negative price:         {zero_price.sum():,}")
print(f"\n--- Overlap ---")
print(f"Null ID + cancellation:      {(null_id & cancel).sum():,}")
print(f"Null ID + non-pos qty:       {(null_id & non_pos_qty).sum():,}")
print(f"Cancel + non-pos qty:        {(cancel & non_pos_qty).sum():,}")
print(f"All three:                   {(null_id & cancel & non_pos_qty).sum():,}")
# Out:
# Total raw rows:              525,461
# Null Customer ID:            107,927
# Cancellations (C-prefix):    10,206
# Non-positive quantity:       12,326
# Zero/negative price:         3,690
#
# --- Overlap ---
# Null ID + cancellation:      367
# Null ID + non-pos qty:       2,487
# Cancel + non-pos qty:        10,205
# All three:                   366

# %%
# ─────────────────────────────────────────────────────────────
# Confirm Line-Item Returns Are Anonymous
# All non-cancel, non-positive qty rows have null Customer ID —
# line-item returns carry no usable customer signal.
# ─────────────────────────────────────────────────────────────

print(df[non_pos_qty & ~cancel & ~null_id].shape)
print(df[non_pos_qty & ~cancel]["Customer ID"].isna().value_counts())
# Out:
# (0, 8)
# Customer ID
# True    2121
# Name: count, dtype: int64

# %%
# ─────────────────────────────────────────────────────────────
# Customer Overlap: Who is cancelling?
# ─────────────────────────────────────────────────────────────

# Identifiable cancellations (have a Customer ID + C-prefix)
id_cancel = df[cancel & ~null_id]

# Current gross purchase customers
gross_customers = set(
    df[
        ~df["Invoice"].astype(str).str.startswith("C") &
        (df["Quantity"] > 0) &
        (df["Price"] > 0) &
        df["Customer ID"].notna()
    ]["Customer ID"].astype(int).astype(str).unique()
)
cancel_customers = set(id_cancel["Customer ID"].astype(int).astype(str).unique())

print(f"Gross purchase customers:      {len(gross_customers):,}")
print(f"Customers with cancellations:  {len(cancel_customers):,}")
print(f"\n--- Overlap with gross customers ---")
print(f"Cancel customers in gross set: {len(cancel_customers & gross_customers):,} "
      f"({len(cancel_customers & gross_customers)/len(cancel_customers):.1%})")
# Out:
# Gross purchase customers:      4,312
# Customers with cancellations:  1,798
#
# --- Overlap with gross customers ---
# Cancel customers in gross set: 1,729 (96.2%)

# %%
# ─────────────────────────────────────────────────────────────
# Data Cleaning
# - Drop rows with missing Customer ID
# - Separate gross purchases and cancellations
# - Compute revenue per line item
# - Normalize data types
# ─────────────────────────────────────────────────────────────

df_clean = df.copy()

# Drop rows without a Customer ID
df_clean = df_clean.dropna(subset=["Customer ID"])

# Normalize data types before splitting
df_clean["Customer ID"] = df_clean["Customer ID"].astype(int).astype(str)
df_clean["Invoice"]     = df_clean["Invoice"].astype(str)
df_clean["InvoiceDate"] = pd.to_datetime(df_clean["InvoiceDate"])

# Separate cancellations (C-prefix invoice) from gross purchases
is_cancellation = df_clean["Invoice"].str.startswith("C")

df_purchases    = df_clean[~is_cancellation & (df_clean["Quantity"] > 0) & (df_clean["Price"] > 0)].copy()
df_cancels      = df_clean[is_cancellation].copy()

# Revenue per line item (gross purchases)
df_purchases["Revenue"] = df_purchases["Quantity"] * df_purchases["Price"]

# Cancelled value per line item (absolute value for aggregation)
df_cancels["Revenue"] = df_cancels["Quantity"].abs() * df_cancels["Price"].abs()

print(f"Gross purchase transactions: {df_purchases.shape[0]:,}")
print(f"Cancellation transactions:   {df_cancels.shape[0]:,}")
# Out:
# Gross purchase transactions: 407,664
# Cancellation transactions:   9,839

# %% [markdown]
# After cleaning, the gross purchase dataset contains **407,664 transactions** across
# 9 columns. Null Customer ID rows (~107,927) are dropped as they cannot be tied
# to a customer. Cancellations (C-prefix invoices) are separated into `df_cancels`
# rather than discarded. The cancellation df contains 9,839 transactions. Diagnostic analysis confirmed 1,798 identifiable
# cancelling customers with 96.2% overlap with the gross purchase population,
# making cancellation rate a viable dissatisfaction feature.

# %%
# ─────────────────────────────────────────────────────────────
# Order-Level Table Construction
# Aggregate gross purchases to one row per order, then join
# per-customer cancellation features as dissatisfaction signals
# ─────────────────────────────────────────────────────────────

# Gross purchase orders
orders = (
    df_purchases
    .groupby(["Customer ID", "Invoice"])
    .agg(
        order_ts      =("InvoiceDate",  "min"),
        total_revenue =("Revenue",      "sum"),
        total_qty     =("Quantity",     "sum"),
        n_items       =("StockCode", "nunique"),
        n_lines       =("StockCode",   "size"),
    )
    .reset_index()
)

# Per-customer cancellation features
cancel_features = (
    df_cancels
    .groupby("Customer ID")
    .agg(
        cancel_count        =("Invoice",  "nunique"),
        total_cancel_value  =("Revenue",  "sum"),
    )
    .reset_index()
)

# Per-customer gross order count (for cancellation_rate denominator)
order_counts = (
    orders
    .groupby("Customer ID")["Invoice"]
    .nunique()
    .reset_index()
    .rename(columns={"Invoice": "gross_order_count"})
)

cancel_features = cancel_features.merge(order_counts, on="Customer ID", how="left")
cancel_features["cancellation_rate"] = (
    cancel_features["cancel_count"] / cancel_features["gross_order_count"]
)

# Join cancellation features onto orders table
orders = orders.merge(cancel_features, on="Customer ID", how="left")

# Customers with no cancellations get 0 for count/value, NaN rate → 0
orders["cancel_count"]       = orders["cancel_count"].fillna(0).astype(int)
orders["total_cancel_value"] = orders["total_cancel_value"].fillna(0)
orders["cancellation_rate"]  = orders["cancellation_rate"].fillna(0)

print("Orders table shape:", orders.shape)
print("Cancellation feature coverage:")
print(f"  Customers with at least one cancellation: {(orders['cancel_count'] > 0).sum():,}")
print(f"  Mean cancellation rate (cancellers only):  {orders[orders['cancel_count'] > 0]['cancellation_rate'].mean():.3f}")
orders.head()
# Out:
# Orders table shape: (19213, 11)
# Cancellation feature coverage:
#   Customers with at least one cancellation: 12,987
#   Mean cancellation rate (cancellers only):  0.331
#   Customer ID Invoice            order_ts  total_revenue  total_qty  n_items  \
# 0       12346  491725 2009-12-14 08:34:00           45.0         10        1
# 1       12346  491742 2009-12-14 11:00:00           22.5          5        1
# 2       12346  491744 2009-12-14 11:02:00           22.5          5        1
# 3       12346  492718 2009-12-18 10:47:00           22.5          5        1
# 4       12346  492722 2009-12-18 10:55:00            1.0          1        1
#
#    n_lines  cancel_count  total_cancel_value  gross_order_count  \
# 0        1             4              437.54               11.0
# 1        1             4              437.54               11.0
# 2        1             4              437.54               11.0
# 3        1             4              437.54               11.0
# ...

# %%
# ─────────────────────────────────────────────────────────────
# Sanity Check — Date Range
# ─────────────────────────────────────────────────────────────

print("Earliest order:", orders["order_ts"].min())
print("Latest order:  ", orders["order_ts"].max())
# Out:
# Earliest order: 2009-12-01 07:45:00
# Latest order:   2010-12-09 20:01:00

# %%
# ─────────────────────────────────────────────────────────────
# Persist Orders Table
# Saved to data/processed/ — excluded from version control
# via .gitignore. Run this notebook to regenerate.
# ─────────────────────────────────────────────────────────────

out = Path("../data/processed")
out.mkdir(parents=True, exist_ok=True)

orders.to_parquet(out / "orders.parquet", index=False)
print("Saved to:", out / "orders.parquet")
print("Shape:", orders.shape)
# Out:
# Saved to: ../data/processed/orders.parquet
# Shape: (19213, 11)

# %% [markdown]
# ## Exploratory Analysis
#
# ### Revenue Distribution

# %%
# ─────────────────────────────────────────────────────────────
# Revenue Distribution — Descriptive Statistics
# ─────────────────────────────────────────────────────────────

print("Revenue:")
print(orders["total_revenue"].describe())

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(orders["total_revenue"], bins=50, edgecolor="none")
axes[0].set_title("Revenue Distribution (Linear Scale)")
axes[0].set_xlabel("Order Revenue ($)")
axes[0].set_ylabel("Count")

axes[1].hist(orders["total_revenue"], bins=50, edgecolor="none", log=False)
axes[1].set_yscale("log")
axes[1].set_title("Revenue Distribution (Log Y Scale)")
axes[1].set_xlabel("Order Revenue ($)")
axes[1].set_ylabel("Count (log)")

plt.tight_layout()
plt.show()
# Out:
# Revenue:
# count    19213.000000
# mean       459.688923
# std        931.129071
# min          0.840000
# 25%        159.380000
# 50%        303.540000
# 75%        484.440000
# max      44051.600000
# Name: total_revenue, dtype: float64

# %%
# ─────────────────────────────────────────────────────────────
# Orders per Customer — Descriptive Statistics
# ─────────────────────────────────────────────────────────────

print("Orders by Customer:")
print(orders.groupby("Customer ID").size().describe())

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

order_counts = orders.groupby("Customer ID")["Invoice"].nunique()

axes[0].hist(order_counts, bins=50, edgecolor="none")
axes[0].set_title("Orders per Customer (Linear Scale)")
axes[0].set_xlabel("Number of Orders")
axes[0].set_ylabel("Count")

axes[1].hist(order_counts, bins=50, edgecolor="none")
axes[1].set_yscale("log")
axes[1].set_title("Orders per Customer (Log Y Scale)")
axes[1].set_xlabel("Number of Orders")
axes[1].set_ylabel("Count (log)")

plt.tight_layout()
plt.show()
# Out:
# Orders by Customer:
# count    4312.000000
# mean        4.455705
# std         8.170213
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max       205.000000
# dtype: float64

# %%
# ─────────────────────────────────────────────────────────────
# Cancellation Distribution
# ─────────────────────────────────────────────────────────────

id_cancel = df[df["Invoice"].astype(str).str.startswith("C") & df["Customer ID"].notna()]
id_cancel = id_cancel.copy()
id_cancel["Customer ID"] = id_cancel["Customer ID"].astype(int).astype(str)
id_cancel["cancel_value"] = id_cancel["Quantity"].abs() * id_cancel["Price"].abs()

cancel_counts = id_cancel.groupby("Customer ID")["Invoice"].nunique()
cancel_value  = id_cancel.groupby("Customer ID")["cancel_value"].sum()

print("Cancellations per customer:")
print(cancel_counts.describe())
print("\nCancelled order value per customer ($):")
print(cancel_value.describe())

fig, axes = plt.subplots(1, 3, figsize=(16, 4))

axes[0].hist(cancel_counts, bins=30, edgecolor="none")
axes[0].set_title("Cancellations per Customer")
axes[0].set_xlabel("Number of Cancellations")
axes[0].set_ylabel("Count")

axes[1].hist(cancel_counts, bins=30, edgecolor="none")
axes[1].set_yscale("log")
axes[1].set_title("Cancellations per Customer (Log Y)")
axes[1].set_xlabel("Number of Cancellations")
axes[1].set_ylabel("Count (log)")

axes[2].hist(cancel_value, bins=50, edgecolor="none")
axes[2].set_yscale("log")
axes[2].set_title("Cancelled Value per Customer (Log Y)")
axes[2].set_xlabel("Total Cancelled Value ($)")
axes[2].set_ylabel("Count (log)")

plt.tight_layout()
plt.show()
# Out:
# Cancellations per customer:
# count    1798.000000
# mean        2.431591
# std         3.318142
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         3.000000
# max        65.000000
# Name: Invoice, dtype: float64
#
# Cancelled order value per customer ($):
# count     1798.000000
# mean       269.073804
# std       1465.316661
# min          0.950000
# 25%         14.950000
# 50%         35.900000
# 75%        105.145000
# max      26477.400000
# Name: cancel_value, dtype: float64

# %% [markdown]
# ## High-Level Observations
#
# ### Revenue Distribution
#
# Customer revenue is **highly right-skewed**, with a small number of customers
# accounting for a disproportionately large share of total revenue. Median order
# revenue is substantially lower than the mean, indicating a long tail of
# high-value orders consistent with bulk purchases or high-frequency buyers.
#
# **Implications for modeling:** Revenue-based features may benefit from log
# scaling. Model performance should be evaluated across customer segments to
# ensure robustness across low- and high-value buyers.
#
# ---
#
# ### Orders per Customer
#
# Order frequency is also **heavily skewed** — most customers place very few
# orders while a small minority place dozens or hundreds. This long-tail
# behavior is typical of retail businesses where a core group of highly engaged
# users coexists with many sporadic or one-time buyers.
#
# **Implications for modeling:** Frequency-based features such as rolling order
# counts are likely to be strong predictors of short-term engagement. Customers
# with limited order history represent a cold-start challenge that simple
# heuristics cannot address, motivating the use of learned time-aware models.
#
# ---
#
# ### Cancellation Distribution
#
# Cancellation behavior mirrors the same right-skew seen in revenue and order
# frequency. The median cancelling customer has only 1 cancellation, 75% have 3
# or fewer, and cancelled value is similarly concentrated — median $35.90 versus
# a mean of $269, with a long tail up to $26,477.
#
# Critically, 96.2% of the 1,798 customers with identifiable cancellations also
# appear in the gross purchase dataset. This high overlap means cancellation
# features will have broad coverage across the training population rather than
# being sparse or missing for most customers.
#
# **Implications for modeling:** Raw cancellation count will be skewed and sparse
# for most customers. Cancellation rate (cancellations / total orders) is a more
# informative feature as it normalizes for customer activity level and captures
# the proportion of a customer's engagement that reversed.
#
# ---
#
# ### Overall Takeaway
#
# The temporal structure and behavioral heterogeneity of this dataset provide
# rich signal for churn modeling despite the relatively small number of raw
# columns. These observations directly motivate:
#
# - Rolling time-window features (7/30/90 days) to capture behavioral recency
#   and frequency at multiple horizons
# - Snapshot-based modeling rather than static customer aggregation
# - Cancellation rate as a dissatisfaction signal alongside gross RFM features
# - Careful comparison against simple recency heuristics to demonstrate the
#   value of a learned model
